# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# df= pd.read_csv("LP_destinations.csv", encoding='utf8')
df=pd.read_csv("LP_destinations.csv",encoding='UTF-8')
df = df.set_index('city')
df.head()
# Out:
#             country                                        description
# city
# Antalya      Turkey  Once seen simply as the gateway to the Turkish...
# Athens       Greece  With equal measures of grunge and grace, Athen...
# Ayia-napa    Cyprus  Endless blue-sky days and a coastline riddled ...
# Bangkok    Thailand  Same same, but different. This Thailish T-shir...
# Barcelona     Spain  Barcelona is an enchanting seaside city with b...

# %%
df['num_of_words'] = df['description'].str.count(' ') + 1
df.head()
# Out:
#             country                                        description  \
# city
# Antalya      Turkey  Once seen simply as the gateway to the Turkish...
# Athens       Greece  With equal measures of grunge and grace, Athen...
# Ayia-napa    Cyprus  Endless blue-sky days and a coastline riddled ...
# Bangkok    Thailand  Same same, but different. This Thailish T-shir...
# Barcelona     Spain  Barcelona is an enchanting seaside city with b...
#
#            num_of_words
# city
# Antalya             112
# Athens              393
# Ayia-napa           147
# Bangkok             390
# Barcelona           419

# %%
df["No_punct_description"] = df["description"].str.replace('[^\w\s]' or "/n",'')
df.head()
# Out:
# C:\Users\danie\AppData\Local\Temp/ipykernel_6400/231955669.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["No_punct_description"] = df["description"].str.replace('[^\w\s]' or "/n",'')
#             country                                        description  \
# city
# Antalya      Turkey  Once seen simply as the gateway to the Turkish...
# Athens       Greece  With equal measures of grunge and grace, Athen...
# Ayia-napa    Cyprus  Endless blue-sky days and a coastline riddled ...
# Bangkok    Thailand  Same same, but different. This Thailish T-shir...
# Barcelona     Spain  Barcelona is an enchanting seaside city with b...
#
#            num_of_words                               No_punct_description
# city
# Antalya             112  Once seen simply as the gateway to the Turkish...
# Athens              393  With equal measures of grunge and grace Athens...
# Ayia-napa           147  Endless bluesky days and a coastline riddled w...
# Bangkok             390  Same same but different This Thailish Tshirt p...
# Barcelona           419  Barcelona is an enchanting seaside city with b...

# %%
df["has_restaurants"]= df.description.str.count("restaurant")
df.head()
# Out:
#             country                                        description  \
# city
# Antalya      Turkey  Once seen simply as the gateway to the Turkish...
# Athens       Greece  With equal measures of grunge and grace, Athen...
# Ayia-napa    Cyprus  Endless blue-sky days and a coastline riddled ...
# Bangkok    Thailand  Same same, but different. This Thailish T-shir...
# Barcelona     Spain  Barcelona is an enchanting seaside city with b...
#
#            num_of_words                               No_punct_description  \
# city
# Antalya             112  Once seen simply as the gateway to the Turkish...
# Athens              393  With equal measures of grunge and grace Athens...
# Ayia-napa           147  Endless bluesky days and a coastline riddled w...
# Bangkok             390  Same same but different This Thailish Tshirt p...
# Barcelona           419  Barcelona is an enchanting seaside city with b...
#
#            has_restaurants
# city
# Antalya                  0
# Athens                   1
# Ayia-napa                0
# Bangkok                  1
# Barcelona                1

# %%
df["has_museums"]= df.description.str.count("museum")
df.head()
# Out:
#             country                                        description  \
# city
# Antalya      Turkey  Once seen simply as the gateway to the Turkish...
# Athens       Greece  With equal measures of grunge and grace, Athen...
# Ayia-napa    Cyprus  Endless blue-sky days and a coastline riddled ...
# Bangkok    Thailand  Same same, but different. This Thailish T-shir...
# Barcelona     Spain  Barcelona is an enchanting seaside city with b...
#
#            num_of_words                               No_punct_description  \
# city
# Antalya             112  Once seen simply as the gateway to the Turkish...
# Athens              393  With equal measures of grunge and grace Athens...
# Ayia-napa           147  Endless bluesky days and a coastline riddled w...
# Bangkok             390  Same same but different This Thailish Tshirt p...
# Barcelona           419  Barcelona is an enchanting seaside city with b...
#
#            has_restaurants  has_museums
# city
# Antalya                  0            1
# Athens                   1            0
# Ayia-napa                0            0
# Bangkok                  1            0
# Barcelona                1            2

# %%
df["has_beaches"]= df.description.str.count("beach|ocean|sea")
df.head()
# Out:
#             country                                        description  \
# city
# Antalya      Turkey  Once seen simply as the gateway to the Turkish...
# Athens       Greece  With equal measures of grunge and grace, Athen...
# Ayia-napa    Cyprus  Endless blue-sky days and a coastline riddled ...
# Bangkok    Thailand  Same same, but different. This Thailish T-shir...
# Barcelona     Spain  Barcelona is an enchanting seaside city with b...
#
#            num_of_words                               No_punct_description  \
# city
# Antalya             112  Once seen simply as the gateway to the Turkish...
# Athens              393  With equal measures of grunge and grace Athens...
# Ayia-napa           147  Endless bluesky days and a coastline riddled w...
# Bangkok             390  Same same but different This Thailish Tshirt p...
# Barcelona           419  Barcelona is an enchanting seaside city with b...
#
#            has_restaurants  has_museums  has_beaches
# city
# Antalya                  0            1            1
# Athens                   1            0            2
# Ayia-napa                0            0            2
# Bangkok                  1            0            0
# Barcelona                1            2            7

# %%
average_of_words=sum(df["num_of_words"])/len(df["num_of_words"])
print("The average of words in the description is: " + str(round(average_of_words,2)))
# Out:
# The average of words in the description is: 265.51

# %%
city_with_longest_description=df["num_of_words"].idxmax()
print("The city with the longest description is: " + city_with_longest_description)
# Out:
# The city with the longest description is: Florence

# %%
hist_num_of_words= df["num_of_words"].plot.hist("city")

# %%
plt.scatter(df["has_beaches"],df["has_restaurants"])
plt.title("Scatter plot of num of beaches vs num of restaurants")
plt.xlabel("num of beaches")
plt.ylabel("num of restaurants")
plt.show()

# %%
plt.scatter(df["has_museums"],df["has_beaches"])
plt.title("Scatter plot of num of museums vs num of beaches")
plt.xlabel("num of museums")
plt.ylabel("num of beaches")
plt.show()
